# %%
import pandas as pd
import json

# %%
file_dir = 'C://Users/17013/uofm/module/08/'

# %%
movies_metadata = pd.read_csv(file_dir+'movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(file_dir+'ratings.csv')

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')

# %%
ratings.sample()
# Out:
#           userId  movieId  rating  timestamp
# 13554585  140922     3494     5.0  995924136

# %%
kaggle_metadata.sample(5)
# Out:
#        adult belongs_to_collection budget  \
# 28816  False                   NaN      0
# 16551  False                   NaN      0
# 7042   False                   NaN      0
# 14319  False                   NaN      0
# 19356  False                   NaN      0
#
#                                                   genres  \
# 28816  [{'id': 18, 'name': 'Drama'}, {'id': 12, 'name...
# 16551  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 7042   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 14319  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 19356  [{'id': 10770, 'name': 'TV Movie'}, {'id': 12,...
#
#                                 homepage      id    imdb_id original_language  \
# 28816                                NaN   38198  tt0095386                fr
# 16551                                NaN   25695  tt1143155                ko
# 7042                                 NaN   26712  tt0043503                en
# 14319                                NaN   69912  tt0060860                en
# 19356  http://www.cryptozoological.co.uk  119698  tt1907779                en
#
#                           original_title  \
# 28816        Itinéraire d'un enfant gâté
# 16551                             나무없는 산
# 7042                        The Enforcer
# 14319  La Prise de Pouvoir Par Louis XIV
# 19356               The Dinosaur Project
#
#                                                 overview  ... release_date  \
# 28816  A foundling, raised in the circus, Sam Lion be...  ...   1988-11-30
# 16551  In Seoul, Korea, two sisters must look after e...  ...   2009-08-27
# 7042   After years of pursuit, Assistant D.A. Martin ...  ...   1951-02-24
# 14319  Cardinal Mazarin dies, leaving a power vacuum ...  ...   1966-10-08
# 19356  Found footage of an expedition into the Congo ...  ...   2012-08-09
#
#       revenue runtime                                   spoken_languages  \
# 28816     0.0   135.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 16551     0.0    89.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 7042      0.0    87.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 14319     0.0    90.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 19356     0.0    83.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#          status                                            tagline  \
# 28816  Released                                                NaN
# 16551  Released                                                NaN
# 7042   Released  "If you're smart you'll come down - if you're ...
# 14319  Released                                                NaN
# 19356  Released  The discovery of a lifetime will become a figh...
#
#                                   title  video vote_average vote_count
# 28816      Itinerary of a Spoiled Child  False          7.6       23.0
# 16551                 Treeless Mountain  False          6.8       13.0
# 7042                       The Enforcer  False          7.4       21.0
# 14319  The Taking of Power by Louis XIV  False          6.9        7.0
# 19356              The Dinosaur Project  False          4.7       63.0
#
# [5 rows x 24 columns]

# %%
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.sample(5)
# Out:
#           userId  movieId  rating   timestamp
# 12506080  129734      994     3.0   880385167
# 25750074  267972     8368     4.0  1413086209
# 7541910    77872    93510     4.0  1332364729
# 3553106    37009    67186     3.0  1379640281
# 16134321  167816    68358     4.0  1311787266
